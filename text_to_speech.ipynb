# %% [markdown]
# <a href="https://colab.research.google.com/github/cloud01available/Machine-learning-projects/blob/main/text_to_speech.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gTTS

# %%
from gtts import gTTS
text_to_say="Rishika is an Idiot"
language="en"
gtts_object = gTTS(text= text_to_say,
                  lang= language,
                  slow=False)
gtts_object.save("/content/gtts.wav")

# %%
from IPython.display import Audio

Audio("/content/gtts.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
french_text = "Bonjour. Je m'appelle Alexandra. Je suis programmeuse."

french_language = "fr"

french_gtts_object = gTTS(text = french_text,
                          lang = french_language,
                          slow = True)

french_gtts_object.save("/content/french.wav")

Audio("/content/french.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
tamil_text = "நான் இன்று சந்தோஷமாக இருக்கிறேன்."

tamil_language = "ta"

tamil_gtts_object = gTTS(text = tamil_text,
                          lang = tamil_language,
                          slow = False)

tamil_gtts_object.save("/content/tamil.wav")

Audio("/content/tamil.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
spanish_text = "Hola, ¿cómo estás?."

spanish_language = "es"

spanish_gtts_object = gTTS(text = spanish_text,
                          lang = spanish_language,
                          slow = False)

spanish_gtts_object.save("/content/spanish.wav")

Audio("/content/spanish.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
german_text = "Hallo, wie geht es dir?."

german_language = "de"

german_gtts_object = gTTS(text = german_text,
                          lang = german_language,
                          slow = False)

german_gtts_object.save("/content/german.wav")

Audio("/content/german.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
japanese_text = "こんにちは、元気ですか."

japanese_language = "ja"

japanese_gtts_object = gTTS(text = japanese_text,
                          lang = japanese_language,
                          slow = False)

japanese_gtts_object.save("/content/japanese.wav")

Audio("/content/japanese.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
korean_text = "안녕하세요, 어떠세요?."

korean_language = "ko"

korean_gtts_object = gTTS(text = korean_text,
                          lang = korean_language,
                          slow = False)

korean_gtts_object.save("/content/korean.wav")

Audio("/content/korean.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
italian_text = "Ciao, come stai?."

italian_language = "it"

italian_gtts_object = gTTS(text = italian_text,
                          lang = italian_language,
                          slow = False)

italian_gtts_object.save("/content/italian.wav")

Audio("/content/italian.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
russian_text = "Привет, как дела?."

russian_language = "ru"

russian_gtts_object = gTTS(text = russian_text,
                          lang = russian_language,
                          slow = False)

russian_gtts_object.save("/content/russian.wav")

Audio("/content/russian.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
portuguese_text = "Olá, como estás?."

portuguese_language = "pt"

portuguese_gtts_object = gTTS(text = portuguese_text,
                          lang = portuguese_language,
                          slow = False)

portuguese_gtts_object.save("/content/portuguese.wav")

Audio("/content/portuguese.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
arabic_text = "مرحبًا، كيف حالك؟."

arabic_language = "ar"

arabic_gtts_object = gTTS(text = arabic_text,
                          lang = arabic_language,
                          slow = False)

arabic_gtts_object.save("/content/arabic.wav")

Audio("/content/arabic.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
hindi_text = "नमस्ते, कैसे हो आप?."

hindi_language = "hi"

hindi_gtts_object = gTTS(text = hindi_text,
                          lang = hindi_language,
                          slow = False)

tamil_gtts_object.save("/content/hindi.wav")

Audio("/content/hindi.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
malayalam_text = "ഹലോ, നിങ്ങൾക്ക് സുഖമാണോ?."

malayalam_language = "ml"

malayalam_gtts_object = gTTS(text = malayalam_text,
                          lang = malayalam_language,
                          slow = False)

malayalam_gtts_object.save("/content/malayalam.wav")

Audio("/content/malayalam.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
telugu_text = "హలో, మీరు ఎలా ఉన్నారు?."

telugu_language = "te"

telugu_gtts_object = gTTS(text = telugu_text,
                          lang = telugu_language,
                          slow = False)

telugu_gtts_object.save("/content/telugu.wav")

Audio("/content/telugu.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
kannada_text = "ಹಲೋ, ನೀವು ಹೇಗಿದ್ದೀರಾ?"

kannada_language = "kn"

kannada_gtts_object = gTTS(text = kannada_text,
                          lang = kannada_language,
                          slow = False)

tamil_gtts_object.save("/content/kannada.wav")

Audio("/content/kannada.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
bengali_text = "হ্যালো, আপনি কেমন আছেন?."

bengali_language = "bn"

bengali_gtts_object = gTTS(text = bengali_text,
                          lang = bengali_language,
                          slow = False)

bengali_gtts_object.save("/content/bengali.wav")

Audio("/content/bengali.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
marathi_text = "नमस्कार, तुम्ही कसे आहात?."

marathi_language = "mr"

marathi_gtts_object = gTTS(text = marathi_text,
                          lang = marathi_language,
                          slow = False)

marathi_gtts_object.save("/content/marathi.wav")

Audio("/content/marathi.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
gujarati_text = "નમસ્તે, તમે કેમ છો?."

gujarati_language = "gu"

gujarati_gtts_object = gTTS(text = gujarati_text,
                          lang = gujarati_language,
                          slow = False)

gujarati_gtts_object.save("/content/gujarati.wav")

Audio("/content/gujarati.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Greek_text = "Γεια σου, πώς είσαι;"

Greek_language = "el"

Greek_gtts_object = gTTS(text = Greek_text,
                          lang = Greek_language,
                          slow = False)

Greek_gtts_object.save("/content/Greek.wav")

Audio("/content/Greek.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
urdu_text = "ہیلو، آپ کیسے ہیں؟."

urdu_language = "ur"

urdu_gtts_object = gTTS(text = urdu_text,
                          lang = urdu_language,
                          slow = False)

urdu_gtts_object.save("/content/urdu.wav")

Audio("/content/urdu.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Step 1: Setup
# !pip install pytesseract
# !sudo apt install tesseract-ocr
from PIL import Image
import pytesseract
import os

# Step 2: Capture Image
from google.colab import files

def upload_image():
    uploaded = files.upload()
    for filename in uploaded.keys():
        return filename

image_file = upload_image()

# Step 3: Text Recognition (OCR)
def ocr(image_path):
    text = pytesseract.image_to_string(Image.open(image_path))
    return text
    print(captured_text)

captured_text = ocr(image_file)

# Step 4: Text-to-Speech (TTS)
# !pip install gTTS

from gtts import gTTS

def text_to_speech(text, language='en'):
    tts = gTTS(text=text, lang=language, slow=False)
    tts.save("output.wav")

text_to_speech(captured_text)

# Step 5: Audio Output
from IPython.display import Audio

Audio("output.wav", autoplay=True)
# Out:
# ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.
#      <input type="file" id="files-19364d0d-0ddd-429f-abf6-874041050295" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-19364d0d-0ddd-429f-abf6-874041050295">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# ...
